# %%
import pandas as pd
import requests, io
import numpy as np
import matplotlib.pyplot as plt

# %%
csv_url_gesamt = "https://opendata.ecdc.europa.eu/covid19/casedistribution/csv"

s=requests.get(csv_url_gesamt).content.decode('utf-8')
c=pd.read_csv(io.StringIO(s))

print("Folgende Spalten enthält der Datensatz:")
for col in c.columns: 
    print("  - " + col)
print("\n"*2)

print("Beispieldatensatz:")
print(c.head(30))
# Out:
# Folgende Spalten enthält der Datensatz:
#   - dateRep
#   - day
#   - month
#   - year
#   - cases
#   - deaths
#   - countriesAndTerritories
#   - geoId
#   - countryterritoryCode
#   - popData2019
#   - continentExp
#   - Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
#
#
#
# Beispieldatensatz:
#        dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0   04/11/2020    4     11  2020     86       4             Afghanistan    AF
# 1   03/11/2020    3     11  2020     95       3             Afghanistan    AF
# 2   02/11/2020    2     11  2020    132       5             Afghanistan    AF
# 3   01/11/2020    1     11  2020     76       0             Afghanistan    AF
# 4   31/10/2020   31     10  2020    157       4             Afghanistan    AF
# 5   30/10/2020   30     10  2020    123       3             Afghanistan    AF
# 6   29/10/2020   29     10  2020      0       0             Afghanistan    AF
# ...

# %% [raw]
# todesfaelle = c["AnzahlTodesfall"].sum()
# infizierte = c["AnzahlFall"].sum()
#
# print("Aktuelle Todesfälle:", todesfaelle)
# print("Aktuelle Infizierte:", infizierte)
# print("Mortalitätsrate    :", round(todesfaelle/infizierte*100, 2), "%")
#
#
# # DEUTSCHLAND
# # Vorbereiten des Datensatzes
# c['Meldedatum'] = pd.to_datetime(c['Meldedatum'])
# tageweise       = c.groupby(c['Meldedatum'])['AnzahlFall'].sum().reset_index()
# y_pos           = np.arange(len(tageweise))
#
# # Plotten mit Matplotlib
# plt.figure(figsize=(20,10))
# plt.bar(y_pos, tageweise["AnzahlFall"], width=0.8)
#
# plt.xticks(y_pos, tageweise["Meldedatum"], rotation=90)
# plt.ylabel('Neuerkrankungen')
# plt.title('Deutschlandweite Neuerkrankungen pro Tag')
#
# plt.show()
#
#
# # NIEDERSACHSEN
# # Vorbereiten des Datensatzes
# c_nds         = c.copy()
# c_nds         = c_nds.loc[c_nds["Bundesland"] == "Niedersachsen"]
# tageweise_nds = c_nds.groupby(c_nds['Meldedatum'])['AnzahlFall'].sum().reset_index()
# y_pos         = np.arange(len(tageweise_nds))
#
# # plotten mit Matplotlib
# plt.figure(figsize=(20,10))
# plt.bar(y_pos, tageweise_nds["AnzahlFall"], width=0.8)
#
# plt.xticks(y_pos, tageweise_nds["Meldedatum"], rotation=90)
# plt.ylabel('Neuerkrankungen')
# plt.title('Niedersachsenweite Neuerkrankungen pro Tag')
#
# plt.show()

# %%
tkinter
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ad1a5acd2072> in <module>
# ----> 1 tkinter
#
# NameError: name 'tkinter' is not defined
